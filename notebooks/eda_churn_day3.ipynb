# %%
import pandas as pd

df = pd.read_csv("../data/Telco_customer_churn.csv")

df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
df.describe(include="all")
# Out:
#         CustomerID   Count        Country       State         City  \
# count         7043  7043.0           7043        7043         7043
# unique        7043     NaN              1           1         1129
# top     3186-AJIEK     NaN  United States  California  Los Angeles
# freq             1     NaN           7043        7043          305
# mean           NaN     1.0            NaN         NaN          NaN
# std            NaN     0.0            NaN         NaN          NaN
# min            NaN     1.0            NaN         NaN          NaN
# 25%            NaN     1.0            NaN         NaN          NaN
# 50%            NaN     1.0            NaN         NaN          NaN
# 75%            NaN     1.0            NaN         NaN          NaN
# max            NaN     1.0            NaN         NaN          NaN
#
#             Zip Code                Lat Long     Latitude    Longitude Gender  \
# count    7043.000000                    7043  7043.000000  7043.000000   7043
# ...

# %% [markdown]
# The dataset contains 7,043 customers
# It has a mix of categorical and numeric features
# There are 33 columns (features)
# Several columns are stored as object (categorical)
# Some columns may require type conversion and cleaning
# Churn is a binary categorical target variable (Yes / No)

# %%
df['Total Charges'].dtype
# Out:
# dtype('O')

# %%
df["Total Charges"] = pd.to_numeric(df["Total Charges"], errors='coerce')

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges          11
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
# DROP rows with missing Total Charges

df = df.dropna(subset=['Total Charges'])

# Verify no more missing values
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5163
# dtype: int64

# %%
df.shape
# Out:
# (7032, 33)

# %%
# Percentage of Churned Customers
churn_distribution = df['Churn Label'].value_counts(normalize=True) * 100
churn_distribution
# Out:
# Churn Label
# No     73.421502
# Yes    26.578498
# Name: proportion, dtype: float64

# %%
# churn by contract
churn_by_contract = df.groupby('Contract')['Churn Label'].value_counts(normalize=True).unstack() * 100
churn_by_contract
# Out:
# Churn Label            No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.722826  11.277174
# Two year        97.151335   2.848665

# %%
# Avg monthly charges by churn vs retained
avg_monthly_charges = df.groupby('Churn Label')['Monthly Charges'].mean()
avg_monthly_charges
# Out:
# Churn Label
# No     61.307408
# Yes    74.441332
# Name: Monthly Charges, dtype: float64

# %%
import matplotlib.pyplot as plt

avg_monthly_charges.plot(kind='bar', color=['green', 'red'])
plt.title('Average Monthly Charges by Churn Status')
plt.ylabel('Average Monthly Charges')
plt.xlabel('Churn Status')
plt.show()

# %% [markdown]
# 1. Two years contracts have the lowest churn rate, while month-to-month contracts have the highest churn rate. This suggests that customers with longer-term commitments are less likely to churn.
# 2. Churned chargers have a higher average monthly charge compared to retained customers, indicating that higher charges may contribute to customer churn.
# 3. the churn rate is approximately 26.5%, meaning that about one in four customers are leaving the service.

# %%
# churn by payment method
churn_by_payment = df.groupby('Payment Method')['Churn Label'].value_counts(normalize=True).unstack() *100
churn_by_payment
# Out:
# Churn Label                       No        Yes
# Payment Method
# Bank transfer (automatic)  83.268482  16.731518
# Credit card (automatic)    84.746877  15.253123
# Electronic check           54.714588  45.285412
# Mailed check               80.798005  19.201995

# %%
# Churn by internet service
churn_by_internet = df.groupby('Internet Service')['Churn Label'].value_counts(normalize=True).unstack() * 100
churn_by_internet
# Out:
# Churn Label              No        Yes
# Internet Service
# DSL               81.001656  18.998344
# Fiber optic       58.107235  41.892765
# No                92.565789   7.434211

# %% [markdown]
# 1. Electronic check payment method has the highest churn rate among all payment methods, suggesting that customers using this method may be more likely to leave the service.
# 2. Electronic check has a 45% churn rate, significantly higher than other payment methods
# 3.Customers with Fiber optic internet service have a higher churn rate compared to those with DSL or No internet service, indicating that the type of internet service may influence customer retention.
# 4. Cumtomers with No internet service have the lowest churn rate at around 8%, while those with Fiber optic service have the highest churn rate at approximately 40%.

# %%
import matplotlib.pyplot as plt

# Visualizing churn distribution
churn_counts = df['Churn Label'].value_counts()

churn_counts.plot(kind='bar')
plt.title('Customer Churn Distribution')
plt.xlabel('Churn Status')
plt.ylabel('Number of Customers')
plt.show()

# %%
churn_contract =( 
    df.groupby('Contract')['Churn Label']
    .value_counts(normalize=True)
    .unstack() 
    * 100
)

# Visualizing churn by contract type

churn_contract.plot(kind='bar')
plt.title('Churn Rate by Contract Type (%)')
plt.ylabel('Percentage')
plt.show()

# %%
# Visualizing churn by internet service
churn_by_internet.plot(kind='bar')
plt.title('Churn Rate by Internet Service (%)')
plt.ylabel('Percentage')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Visualizing churn by payment method

churn_by_payment.plot(kind='bar') 
plt.title('Churn Rate by Payment Method (%)')
plt.ylabel('Percentage')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Charges vs Churn (Pricing Analysis)

df.boxplot(column='Monthly Charges', by='Churn Label')
plt.title('Monthly Charges by Churn Status')
plt.suptitle('')
plt.ylabel('Monthly Charges')
plt.show()

# %% [markdown]
# KEY INSIGHTS:
# Month to month customers have higher churn rates and higher monthly charges
# Electronic check payment method has the highest churn rate
# Fiber optic internet service has higher churn rates compared to DSL and No internet
# High monthly charges are associated with higher churn rates
#
#
# Product Recommendations:
# 1. Introduce incentives for month-to-month customers to switch to longer-term contracts (e.g., 1-year or 2-year) to reduce churn.
# 2. Promote auto-pay or card payment methods to lower churn rates associated with electronic check payments.
# 3. Offer competitive pricing or bundled services for fiber optic internet customers to enhance retention.
# 4. Improve Fiber optic onboarding experience and customer support to reduce churn.
# 5. Implement targeted retention campaigns for high monthly charge customers, such as loyalty programs or discounts.

# %%
df.to_csv("../data/Telco_customer_churn_cleaned.csv", index=False)
